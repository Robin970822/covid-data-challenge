# %% [markdown]
# # Data imputation
# [TOC]

# %%
import os
import pandas as pd
import numpy as np
from fancyimpute import KNN, NuclearNormMinimization, SoftImpute, IterativeImputer, BiScaler

from data import feature, get_severity, z_score_normalize, z_score_denormalize, fill_dataset
# Out:
# Using TensorFlow backend.
# D:\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\71774\AppData\Roaming\Python\Python37\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\71774\AppData\Roaming\Python\Python37\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\71774\AppData\Roaming\Python\Python37\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\71774\AppData\Roaming\Python\Python37\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\71774\AppData\Roaming\Python\Python37\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\71774\AppData\Roaming\Python\Python37\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Read data

# %%
train_data_path = './trainSet/trainSet.txt'
test_data_path = './testSet/testSet.txt'

# %%
train_dataset = pd.read_csv(train_data_path, sep=',')
train_dataset['severity'] = train_dataset['Prognosis'].map(get_severity)
test_dataset = pd.read_csv(test_data_path, sep=',')

y = np.array(train_dataset['severity'])

# %% [markdown]
# ## Imputation
# ### Impute testing dataset
# - Filled NaN data using [method] based on concatenation of trainSet.txt & testSet.txt.
# - There are columns filled with **NaN** so we need **concatenation** of trainSet.txt & testSet.txt, otherwise nothing meaningful imputation can be obtained.

# %%
concat_feature = pd.concat([test_dataset[feature], train_dataset[feature]])
test_dataset_len = len(test_dataset)
train_dataset_len = len(train_dataset)

# %%
X_incomplete = concat_feature
X_incomplete = np.array(X_incomplete)
X_incomplete = z_score_normalize(X_incomplete)

X_filled_knn_3 = KNN(k=3).fit_transform(X_incomplete)
X_filled_knn_6 = KNN(k=6).fit_transform(X_incomplete)
X_filled_knn_9 = KNN(k=9).fit_transform(X_incomplete)

# Not suitable for large scale matrix
# X_filled_nnm = NuclearNormMinimization().fit_transform(X_incomplete)

X_incomplete_normalized = BiScaler().fit_transform(X_incomplete)
X_filled_softimpute = SoftImpute().fit_transform(X_incomplete_normalized)

test_dataset_filled_knn_3 = fill_dataset(test_dataset, feature, z_score_denormalize(X_filled_knn_3[:test_dataset_len]), './csv/filled_testSet/filled_knn_3_testSet_binary.txt')
test_dataset_filled_knn_6 = fill_dataset(test_dataset, feature, z_score_denormalize(X_filled_knn_6[:test_dataset_len]), './csv/filled_testSet/filled_knn_6_testSet_binary.txt')
test_dataset_filled_knn_9 = fill_dataset(test_dataset, feature, z_score_denormalize(X_filled_knn_9[:test_dataset_len]), './csv/filled_testSet/filled_knn_9_testSet_binary.txt')
test_dataset_filled_softimpute = fill_dataset(test_dataset, feature, z_score_denormalize(X_filled_softimpute[:test_dataset_len]), './csv/filled_testSet/filled_softimpute_testSet_binary.txt')
# Out:
# Imputing row 1/983 with 4 missing, elapsed time: 0.173
# Imputing row 101/983 with 9 missing, elapsed time: 0.183
# Imputing row 201/983 with 4 missing, elapsed time: 0.189
# Imputing row 301/983 with 6 missing, elapsed time: 0.194
# Imputing row 401/983 with 3 missing, elapsed time: 0.199
# Imputing row 501/983 with 1 missing, elapsed time: 0.204
# Imputing row 601/983 with 3 missing, elapsed time: 0.210
# Imputing row 701/983 with 4 missing, elapsed time: 0.214
# Imputing row 801/983 with 3 missing, elapsed time: 0.220
# Imputing row 901/983 with 1 missing, elapsed time: 0.225
# Imputing row 1/983 with 4 missing, elapsed time: 0.168
# Imputing row 101/983 with 9 missing, elapsed time: 0.178
# Imputing row 201/983 with 4 missing, elapsed time: 0.183
# Imputing row 301/983 with 6 missing, elapsed time: 0.187
# Imputing row 401/983 with 3 missing, elapsed time: 0.193
# Imputing row 501/983 with 1 missing, elapsed time: 0.197
# Imputing row 601/983 with 3 missing, elapsed time: 0.203
# Imputing row 701/983 with 4 missing, elapsed time: 0.207
# Imputing row 801/983 with 3 missing, elapsed time: 0.213
# Imputing row 901/983 with 1 missing, elapsed time: 0.218
# Imputing row 1/983 with 4 missing, elapsed time: 0.168
# Imputing row 101/983 with 9 missing, elapsed time: 0.177
# Imputing row 201/983 with 4 missing, elapsed time: 0.184
# Imputing row 301/983 with 6 missing, elapsed time: 0.187
# Imputing row 401/983 with 3 missing, elapsed time: 0.193
# Imputing row 501/983 with 1 missing, elapsed time: 0.197
# Imputing row 601/983 with 3 missing, elapsed time: 0.203
# Imputing row 701/983 with 4 missing, elapsed time: 0.207
# Imputing row 801/983 with 3 missing, elapsed time: 0.213
# Imputing row 901/983 with 1 missing, elapsed time: 0.217
# [BiScaler] Initial log residual value = 7.224592
# [BiScaler] Iter 1: log residual = 4.014402, log improvement ratio=3.210189
# [BiScaler] Iter 2: log residual = 3.591567, log improvement ratio=0.422835
# [BiScaler] Iter 3: log residual = 3.148033, log improvement ratio=0.443535
# [BiScaler] Iter 4: log residual = 2.273583, log improvement ratio=0.874450
# [BiScaler] Iter 5: log residual = 0.994819, log improvement ratio=1.278764
# [BiScaler] Iter 6: log residual = -0.419327, log improvement ratio=1.414145
# [BiScaler] Iter 7: log residual = -1.849249, log improvement ratio=1.429922
# [BiScaler] Iter 8: log residual = -3.270333, log improvement ratio=1.421084
# [BiScaler] Iter 9: log residual = -4.679995, log improvement ratio=1.409663
# [BiScaler] Iter 10: log residual = -6.078985, log improvement ratio=1.398990
# [BiScaler] Iter 11: log residual = -7.468283, log improvement ratio=1.389298
# [BiScaler] Iter 12: log residual = -8.848790, log improvement ratio=1.380507
# [BiScaler] Iter 13: log residual = -10.221356, log improvement ratio=1.372566
# [BiScaler] Iter 14: log residual = -11.586803, log improvement ratio=1.365447
# [BiScaler] Iter 15: log residual = -12.945929, log improvement ratio=1.359126
# [BiScaler] Iter 16: log residual = -14.299495, log improvement ratio=1.353566
# [BiScaler] Iter 17: log residual = -15.648215, log improvement ratio=1.348720
# [BiScaler] Iter 18: log residual = -16.992745, log improvement ratio=1.344530
# [BiScaler] Iter 19: log residual = -18.333676, log improvement ratio=1.340931
# [BiScaler] Iter 20: log residual = -19.671533, log improvement ratio=1.337857
# [BiScaler] Iter 21: log residual = -21.006778, log improvement ratio=1.335245
# [BiScaler] Iter 22: log residual = -22.339809, log improvement ratio=1.333031
# [BiScaler] Iter 23: log residual = -23.670969, log improvement ratio=1.331160
# [BiScaler] Iter 24: log residual = -25.000552, log improvement ratio=1.329582
# [BiScaler] Iter 25: log residual = -26.328804, log improvement ratio=1.328252
# [BiScaler] Iter 26: log residual = -27.655936, log improvement ratio=1.327132
# [BiScaler] Iter 27: log residual = -28.982124, log improvement ratio=1.326187
# [BiScaler] Iter 28: log residual = -30.307514, log improvement ratio=1.325391
# [BiScaler] Iter 29: log residual = -31.632233, log improvement ratio=1.324719
# [BiScaler] Iter 30: log residual = -32.956383, log improvement ratio=1.324150
# [BiScaler] Iter 31: log residual = -34.280051, log improvement ratio=1.323668
# [BiScaler] Iter 32: log residual = -35.603310, log improvement ratio=1.323259
# [BiScaler] Iter 33: log residual = -36.926222, log improvement ratio=1.322912
# [BiScaler] Iter 34: log residual = -38.248839, log improvement ratio=1.322616
# [BiScaler] Iter 35: log residual = -39.571199, log improvement ratio=1.322361
# [BiScaler] Iter 36: log residual = -40.893335, log improvement ratio=1.322136
# [BiScaler] Iter 37: log residual = -42.215302, log improvement ratio=1.321967
# [BiScaler] Iter 38: log residual = -43.537118, log improvement ratio=1.321816
# [BiScaler] Iter 39: log residual = -44.858761, log improvement ratio=1.321643
# [BiScaler] Iter 40: log residual = -46.180338, log improvement ratio=1.321577
# [BiScaler] Iter 41: log residual = -47.501593, log improvement ratio=1.321255
# [BiScaler] Iter 42: log residual = -48.822982, log improvement ratio=1.321389
# [BiScaler] Iter 43: log residual = -50.144523, log improvement ratio=1.321541
# [BiScaler] Iter 44: log residual = -51.465531, log improvement ratio=1.321008
# [BiScaler] Iter 45: log residual = -52.785982, log improvement ratio=1.320452
# [BiScaler] Iter 46: log residual = -54.104839, log improvement ratio=1.318857
# [BiScaler] Iter 47: log residual = -55.429235, log improvement ratio=1.324396
# [BiScaler] Iter 48: log residual = -56.731940, log improvement ratio=1.302705
# [BiScaler] Iter 49: log residual = -58.088693, log improvement ratio=1.356753
# [BiScaler] Iter 50: log residual = -59.331699, log improvement ratio=1.243007
# [BiScaler] Iter 51: log residual = -60.657052, log improvement ratio=1.325352
# [BiScaler] Iter 52: log residual = -61.942604, log improvement ratio=1.285552
# [BiScaler] Iter 53: log residual = -63.101970, log improvement ratio=1.159366
# [BiScaler] Iter 54: log residual = -64.018406, log improvement ratio=0.916436
# [BiScaler] Iter 55: log residual = -64.492161, log improvement ratio=0.473755
# [BiScaler] Iter 56: log residual = -64.485011, log improvement ratio=-0.007149
# [SoftImpute] Max Singular Value of X_init = 41.299704
# [SoftImpute] Iter 1: observed MAE=0.023429 rank=15
# [SoftImpute] Iter 2: observed MAE=0.023433 rank=15
# [SoftImpute] Iter 3: observed MAE=0.023439 rank=15
# [SoftImpute] Iter 4: observed MAE=0.023445 rank=15
# [SoftImpute] Iter 5: observed MAE=0.023451 rank=15
# [SoftImpute] Iter 6: observed MAE=0.023457 rank=15
# [SoftImpute] Iter 7: observed MAE=0.023464 rank=15
# [SoftImpute] Iter 8: observed MAE=0.023469 rank=15
# [SoftImpute] Iter 9: observed MAE=0.023474 rank=15
# [SoftImpute] Iter 10: observed MAE=0.023479 rank=15
# [SoftImpute] Iter 11: observed MAE=0.023484 rank=15
# [SoftImpute] Iter 12: observed MAE=0.023488 rank=15
# [SoftImpute] Iter 13: observed MAE=0.023492 rank=15
# [SoftImpute] Iter 14: observed MAE=0.023495 rank=15
# [SoftImpute] Iter 15: observed MAE=0.023499 rank=15
# [SoftImpute] Iter 16: observed MAE=0.023502 rank=15
# [SoftImpute] Iter 17: observed MAE=0.023505 rank=15
# [SoftImpute] Iter 18: observed MAE=0.023507 rank=15
# [SoftImpute] Iter 19: observed MAE=0.023510 rank=15
# [SoftImpute] Iter 20: observed MAE=0.023513 rank=15
# [SoftImpute] Iter 21: observed MAE=0.023516 rank=15
# [SoftImpute] Iter 22: observed MAE=0.023518 rank=15
# [SoftImpute] Iter 23: observed MAE=0.023520 rank=15
# [SoftImpute] Iter 24: observed MAE=0.023523 rank=15
# [SoftImpute] Iter 25: observed MAE=0.023525 rank=15
# [SoftImpute] Iter 26: observed MAE=0.023527 rank=15
# [SoftImpute] Iter 27: observed MAE=0.023529 rank=15
# [SoftImpute] Iter 28: observed MAE=0.023531 rank=15
# [SoftImpute] Iter 29: observed MAE=0.023533 rank=15
# [SoftImpute] Iter 30: observed MAE=0.023534 rank=15
# [SoftImpute] Iter 31: observed MAE=0.023536 rank=15
# [SoftImpute] Iter 32: observed MAE=0.023538 rank=15
# [SoftImpute] Iter 33: observed MAE=0.023539 rank=15
# [SoftImpute] Iter 34: observed MAE=0.023541 rank=15
# [SoftImpute] Iter 35: observed MAE=0.023542 rank=15
# [SoftImpute] Iter 36: observed MAE=0.023544 rank=15
# [SoftImpute] Iter 37: observed MAE=0.023545 rank=15
# [SoftImpute] Iter 38: observed MAE=0.023546 rank=15
# [SoftImpute] Iter 39: observed MAE=0.023547 rank=15
# [SoftImpute] Iter 40: observed MAE=0.023549 rank=15
# [SoftImpute] Iter 41: observed MAE=0.023550 rank=15
# [SoftImpute] Iter 42: observed MAE=0.023551 rank=15
# [SoftImpute] Iter 43: observed MAE=0.023552 rank=15
# [SoftImpute] Iter 44: observed MAE=0.023553 rank=15
# [SoftImpute] Iter 45: observed MAE=0.023554 rank=15
# [SoftImpute] Iter 46: observed MAE=0.023555 rank=15
# [SoftImpute] Iter 47: observed MAE=0.023556 rank=15
# [SoftImpute] Iter 48: observed MAE=0.023557 rank=15
# [SoftImpute] Iter 49: observed MAE=0.023558 rank=15
# [SoftImpute] Iter 50: observed MAE=0.023559 rank=15
# [SoftImpute] Iter 51: observed MAE=0.023560 rank=15
# [SoftImpute] Iter 52: observed MAE=0.023561 rank=15
# [SoftImpute] Iter 53: observed MAE=0.023561 rank=15
# [SoftImpute] Iter 54: observed MAE=0.023562 rank=15
# [SoftImpute] Iter 55: observed MAE=0.023563 rank=15
# [SoftImpute] Iter 56: observed MAE=0.023564 rank=15
# [SoftImpute] Iter 57: observed MAE=0.023564 rank=15
# [SoftImpute] Iter 58: observed MAE=0.023565 rank=15
# [SoftImpute] Iter 59: observed MAE=0.023566 rank=15
# [SoftImpute] Iter 60: observed MAE=0.023566 rank=15
# [SoftImpute] Iter 61: observed MAE=0.023567 rank=15
# [SoftImpute] Iter 62: observed MAE=0.023568 rank=15
# [SoftImpute] Iter 63: observed MAE=0.023568 rank=15
# [SoftImpute] Iter 64: observed MAE=0.023569 rank=15
# [SoftImpute] Iter 65: observed MAE=0.023569 rank=15
# [SoftImpute] Iter 66: observed MAE=0.023570 rank=15
# [SoftImpute] Iter 67: observed MAE=0.023570 rank=15
# [SoftImpute] Iter 68: observed MAE=0.023571 rank=15
# [SoftImpute] Iter 69: observed MAE=0.023572 rank=15
# [SoftImpute] Iter 70: observed MAE=0.023572 rank=15
# [SoftImpute] Iter 71: observed MAE=0.023573 rank=15
# [SoftImpute] Iter 72: observed MAE=0.023573 rank=15
# [SoftImpute] Iter 73: observed MAE=0.023573 rank=15
# [SoftImpute] Iter 74: observed MAE=0.023574 rank=15
# [SoftImpute] Iter 75: observed MAE=0.023574 rank=15
# [SoftImpute] Iter 76: observed MAE=0.023575 rank=15
# [SoftImpute] Iter 77: observed MAE=0.023575 rank=15
# [SoftImpute] Iter 78: observed MAE=0.023576 rank=15
# [SoftImpute] Iter 79: observed MAE=0.023576 rank=15
# [SoftImpute] Iter 80: observed MAE=0.023576 rank=15
# [SoftImpute] Iter 81: observed MAE=0.023577 rank=15
# [SoftImpute] Iter 82: observed MAE=0.023577 rank=15
# [SoftImpute] Iter 83: observed MAE=0.023577 rank=15
# [SoftImpute] Iter 84: observed MAE=0.023578 rank=15
# [SoftImpute] Iter 85: observed MAE=0.023578 rank=15
# [SoftImpute] Iter 86: observed MAE=0.023578 rank=15
# [SoftImpute] Iter 87: observed MAE=0.023579 rank=15
# [SoftImpute] Iter 88: observed MAE=0.023579 rank=15
# [SoftImpute] Iter 89: observed MAE=0.023579 rank=15
# [SoftImpute] Iter 90: observed MAE=0.023580 rank=15
# [SoftImpute] Iter 91: observed MAE=0.023580 rank=15
# [SoftImpute] Iter 92: observed MAE=0.023580 rank=15
# [SoftImpute] Iter 93: observed MAE=0.023580 rank=15
# [SoftImpute] Iter 94: observed MAE=0.023581 rank=15
# [SoftImpute] Iter 95: observed MAE=0.023581 rank=15
# [SoftImpute] Iter 96: observed MAE=0.023581 rank=15
# [SoftImpute] Iter 97: observed MAE=0.023581 rank=15
# [SoftImpute] Iter 98: observed MAE=0.023582 rank=15
# [SoftImpute] Iter 99: observed MAE=0.023582 rank=15
# [SoftImpute] Iter 100: observed MAE=0.023582 rank=15
# [SoftImpute] Stopped after iteration 100 for lambda=0.825994

# %% [markdown]
# ### Impute training dataset

# %%
X_incomplete = train_dataset[feature]
X_incomplete = np.array(X_incomplete)
X_incomplete = z_score_normalize(X_incomplete)
X_filled_knn_3 = KNN(k=3).fit_transform(X_incomplete)
X_filled_knn_6 = KNN(k=6).fit_transform(X_incomplete)
X_filled_knn_9 = KNN(k=9).fit_transform(X_incomplete)

# Not suitable for large scale matrix
# X_filled_nnm = NuclearNormMinimization().fit_transform(X_incomplete)

X_incomplete_normalized = BiScaler().fit_transform(X_incomplete)
X_filled_softimpute = SoftImpute().fit_transform(X_incomplete_normalized)

fill_dataset(train_dataset, feature, z_score_denormalize(X_filled_knn_3), './csv/filled_trainSet/filled_knn_3_trainSet_binary.txt')
fill_dataset(train_dataset, feature, z_score_denormalize(X_filled_knn_6), './csv/filled_trainSet/filled_knn_6_trainSet_binary.txt')
fill_dataset(train_dataset, feature, z_score_denormalize(X_filled_knn_9), './csv/filled_trainSet/filled_knn_9_trainSet_binary.txt')
fill_dataset(train_dataset, feature, z_score_denormalize(X_filled_softimpute), './csv/filled_trainSet/filled_softimpute_trainSet_binary.txt')
# Out:
# Imputing row 1/863 with 4 missing, elapsed time: 0.127
# Imputing row 101/863 with 1 missing, elapsed time: 0.131
# Imputing row 201/863 with 2 missing, elapsed time: 0.136
# Imputing row 301/863 with 3 missing, elapsed time: 0.142
# Imputing row 401/863 with 5 missing, elapsed time: 0.147
# Imputing row 501/863 with 3 missing, elapsed time: 0.152
# Imputing row 601/863 with 4 missing, elapsed time: 0.156
# Imputing row 701/863 with 2 missing, elapsed time: 0.162
# Imputing row 801/863 with 2 missing, elapsed time: 0.166
# Imputing row 1/863 with 4 missing, elapsed time: 0.123
# Imputing row 101/863 with 1 missing, elapsed time: 0.127
# Imputing row 201/863 with 2 missing, elapsed time: 0.132
# Imputing row 301/863 with 3 missing, elapsed time: 0.137
# Imputing row 401/863 with 5 missing, elapsed time: 0.142
# Imputing row 501/863 with 3 missing, elapsed time: 0.147
# Imputing row 601/863 with 4 missing, elapsed time: 0.151
# Imputing row 701/863 with 2 missing, elapsed time: 0.156
# Imputing row 801/863 with 2 missing, elapsed time: 0.161
# Imputing row 1/863 with 4 missing, elapsed time: 0.127
# Imputing row 101/863 with 1 missing, elapsed time: 0.132
# Imputing row 201/863 with 2 missing, elapsed time: 0.137
# Imputing row 301/863 with 3 missing, elapsed time: 0.142
# Imputing row 401/863 with 5 missing, elapsed time: 0.147
# Imputing row 501/863 with 3 missing, elapsed time: 0.152
# Imputing row 601/863 with 4 missing, elapsed time: 0.157
# Imputing row 701/863 with 2 missing, elapsed time: 0.162
# Imputing row 801/863 with 2 missing, elapsed time: 0.167
# [BiScaler] Initial log residual value = 7.011538
# [BiScaler] Iter 1: log residual = 3.895898, log improvement ratio=3.115640
# [BiScaler] Iter 2: log residual = 3.435541, log improvement ratio=0.460357
# [BiScaler] Iter 3: log residual = 2.898928, log improvement ratio=0.536613
# [BiScaler] Iter 4: log residual = 1.866424, log improvement ratio=1.032503
# [BiScaler] Iter 5: log residual = 0.477144, log improvement ratio=1.389280
# [BiScaler] Iter 6: log residual = -0.994577, log improvement ratio=1.471721
# [BiScaler] Iter 7: log residual = -2.462247, log improvement ratio=1.467669
# [BiScaler] Iter 8: log residual = -3.913295, log improvement ratio=1.451049
# [BiScaler] Iter 9: log residual = -5.348104, log improvement ratio=1.434808
# [BiScaler] Iter 10: log residual = -6.768317, log improvement ratio=1.420214
# [BiScaler] Iter 11: log residual = -8.175501, log improvement ratio=1.407184
# [BiScaler] Iter 12: log residual = -9.571131, log improvement ratio=1.395630
# [BiScaler] Iter 13: log residual = -10.956636, log improvement ratio=1.385505
# [BiScaler] Iter 14: log residual = -12.333393, log improvement ratio=1.376756
# [BiScaler] Iter 15: log residual = -13.702693, log improvement ratio=1.369300
# [BiScaler] Iter 16: log residual = -15.065720, log improvement ratio=1.363027
# [BiScaler] Iter 17: log residual = -16.423526, log improvement ratio=1.357807
# [BiScaler] Iter 18: log residual = -17.777031, log improvement ratio=1.353505
# [BiScaler] Iter 19: log residual = -19.127019, log improvement ratio=1.349988
# [BiScaler] Iter 20: log residual = -20.474151, log improvement ratio=1.347131
# [BiScaler] Iter 21: log residual = -21.818973, log improvement ratio=1.344823
# [BiScaler] Iter 22: log residual = -23.161938, log improvement ratio=1.342964
# [BiScaler] Iter 23: log residual = -24.503411, log improvement ratio=1.341474
# [BiScaler] Iter 24: log residual = -25.843691, log improvement ratio=1.340280
# [BiScaler] Iter 25: log residual = -27.183017, log improvement ratio=1.339326
# [BiScaler] Iter 26: log residual = -28.521582, log improvement ratio=1.338564
# [BiScaler] Iter 27: log residual = -29.859538, log improvement ratio=1.337956
# [BiScaler] Iter 28: log residual = -31.197008, log improvement ratio=1.337470
# [BiScaler] Iter 29: log residual = -32.534091, log improvement ratio=1.337083
# [BiScaler] Iter 30: log residual = -33.870864, log improvement ratio=1.336773
# [BiScaler] Iter 31: log residual = -35.207388, log improvement ratio=1.336525
# [BiScaler] Iter 32: log residual = -36.543714, log improvement ratio=1.336326
# [BiScaler] Iter 33: log residual = -37.879882, log improvement ratio=1.336168
# [BiScaler] Iter 34: log residual = -39.215920, log improvement ratio=1.336038
# [BiScaler] Iter 35: log residual = -40.551850, log improvement ratio=1.335931
# [BiScaler] Iter 36: log residual = -41.887700, log improvement ratio=1.335849
# [BiScaler] Iter 37: log residual = -43.223505, log improvement ratio=1.335805
# [BiScaler] Iter 38: log residual = -44.559201, log improvement ratio=1.335696
# [BiScaler] Iter 39: log residual = -45.894945, log improvement ratio=1.335744
# [BiScaler] Iter 40: log residual = -47.230412, log improvement ratio=1.335467
# [BiScaler] Iter 41: log residual = -48.566227, log improvement ratio=1.335815
# [BiScaler] Iter 42: log residual = -49.902206, log improvement ratio=1.335979
# [BiScaler] Iter 43: log residual = -51.237384, log improvement ratio=1.335178
# [BiScaler] Iter 44: log residual = -52.570832, log improvement ratio=1.333449
# [BiScaler] Iter 45: log residual = -53.912013, log improvement ratio=1.341181
# [BiScaler] Iter 46: log residual = -55.242479, log improvement ratio=1.330466
# [BiScaler] Iter 47: log residual = -56.587122, log improvement ratio=1.344643
# [BiScaler] Iter 48: log residual = -57.904940, log improvement ratio=1.317818
# [BiScaler] Iter 49: log residual = -59.202998, log improvement ratio=1.298058
# [BiScaler] Iter 50: log residual = -60.569503, log improvement ratio=1.366505
# [BiScaler] Iter 51: log residual = -61.817416, log improvement ratio=1.247913
# [BiScaler] Iter 52: log residual = -62.977669, log improvement ratio=1.160253
# [BiScaler] Iter 53: log residual = -63.885486, log improvement ratio=0.907817
# [BiScaler] Iter 54: log residual = -64.303222, log improvement ratio=0.417736
# [BiScaler] Iter 55: log residual = -64.778965, log improvement ratio=0.475743
# [BiScaler] Iter 56: log residual = -64.234897, log improvement ratio=-0.544068
# [SoftImpute] Max Singular Value of X_init = 39.629067
# [SoftImpute] Iter 1: observed MAE=0.023503 rank=15
# [SoftImpute] Iter 2: observed MAE=0.023508 rank=15
# [SoftImpute] Iter 3: observed MAE=0.023515 rank=15
# [SoftImpute] Iter 4: observed MAE=0.023523 rank=15
# [SoftImpute] Iter 5: observed MAE=0.023531 rank=15
# [SoftImpute] Iter 6: observed MAE=0.023539 rank=15
# [SoftImpute] Iter 7: observed MAE=0.023546 rank=15
# [SoftImpute] Iter 8: observed MAE=0.023553 rank=15
# [SoftImpute] Iter 9: observed MAE=0.023559 rank=15
# [SoftImpute] Iter 10: observed MAE=0.023565 rank=15
# [SoftImpute] Iter 11: observed MAE=0.023571 rank=15
# [SoftImpute] Iter 12: observed MAE=0.023576 rank=15
# [SoftImpute] Iter 13: observed MAE=0.023581 rank=15
# [SoftImpute] Iter 14: observed MAE=0.023586 rank=15
# [SoftImpute] Iter 15: observed MAE=0.023591 rank=15
# [SoftImpute] Iter 16: observed MAE=0.023595 rank=15
# [SoftImpute] Iter 17: observed MAE=0.023598 rank=15
# [SoftImpute] Iter 18: observed MAE=0.023602 rank=15
# [SoftImpute] Iter 19: observed MAE=0.023605 rank=15
# [SoftImpute] Iter 20: observed MAE=0.023608 rank=15
# [SoftImpute] Iter 21: observed MAE=0.023611 rank=15
# [SoftImpute] Iter 22: observed MAE=0.023614 rank=15
# [SoftImpute] Iter 23: observed MAE=0.023617 rank=15
# [SoftImpute] Iter 24: observed MAE=0.023619 rank=15
# [SoftImpute] Iter 25: observed MAE=0.023622 rank=15
# [SoftImpute] Iter 26: observed MAE=0.023624 rank=15
# [SoftImpute] Iter 27: observed MAE=0.023626 rank=15
# [SoftImpute] Iter 28: observed MAE=0.023628 rank=15
# [SoftImpute] Iter 29: observed MAE=0.023630 rank=15
# [SoftImpute] Iter 30: observed MAE=0.023632 rank=15
# [SoftImpute] Iter 31: observed MAE=0.023634 rank=15
# [SoftImpute] Iter 32: observed MAE=0.023636 rank=15
# [SoftImpute] Iter 33: observed MAE=0.023638 rank=15
# [SoftImpute] Iter 34: observed MAE=0.023640 rank=15
# [SoftImpute] Iter 35: observed MAE=0.023642 rank=15
# [SoftImpute] Iter 36: observed MAE=0.023644 rank=15
# [SoftImpute] Iter 37: observed MAE=0.023646 rank=15
# [SoftImpute] Iter 38: observed MAE=0.023647 rank=15
# [SoftImpute] Iter 39: observed MAE=0.023649 rank=15
# [SoftImpute] Iter 40: observed MAE=0.023650 rank=15
# [SoftImpute] Iter 41: observed MAE=0.023652 rank=15
# [SoftImpute] Iter 42: observed MAE=0.023653 rank=15
# [SoftImpute] Iter 43: observed MAE=0.023654 rank=15
# [SoftImpute] Iter 44: observed MAE=0.023656 rank=15
# [SoftImpute] Iter 45: observed MAE=0.023657 rank=15
# [SoftImpute] Iter 46: observed MAE=0.023658 rank=15
# [SoftImpute] Iter 47: observed MAE=0.023659 rank=15
# [SoftImpute] Iter 48: observed MAE=0.023660 rank=15
# [SoftImpute] Iter 49: observed MAE=0.023661 rank=15
# [SoftImpute] Iter 50: observed MAE=0.023662 rank=15
# [SoftImpute] Iter 51: observed MAE=0.023663 rank=15
# [SoftImpute] Iter 52: observed MAE=0.023664 rank=15
# [SoftImpute] Iter 53: observed MAE=0.023665 rank=15
# [SoftImpute] Iter 54: observed MAE=0.023666 rank=15
# [SoftImpute] Iter 55: observed MAE=0.023666 rank=15
# [SoftImpute] Iter 56: observed MAE=0.023667 rank=15
# [SoftImpute] Iter 57: observed MAE=0.023668 rank=15
# [SoftImpute] Iter 58: observed MAE=0.023669 rank=15
# [SoftImpute] Iter 59: observed MAE=0.023669 rank=15
# [SoftImpute] Iter 60: observed MAE=0.023670 rank=15
# [SoftImpute] Iter 61: observed MAE=0.023671 rank=15
# [SoftImpute] Iter 62: observed MAE=0.023672 rank=15
# [SoftImpute] Iter 63: observed MAE=0.023672 rank=15
# [SoftImpute] Iter 64: observed MAE=0.023673 rank=15
# [SoftImpute] Iter 65: observed MAE=0.023673 rank=15
# [SoftImpute] Iter 66: observed MAE=0.023674 rank=15
# [SoftImpute] Iter 67: observed MAE=0.023674 rank=15
# [SoftImpute] Iter 68: observed MAE=0.023675 rank=15
# [SoftImpute] Iter 69: observed MAE=0.023676 rank=15
# [SoftImpute] Iter 70: observed MAE=0.023676 rank=15
# [SoftImpute] Iter 71: observed MAE=0.023677 rank=15
# [SoftImpute] Iter 72: observed MAE=0.023677 rank=15
# [SoftImpute] Iter 73: observed MAE=0.023678 rank=15
# [SoftImpute] Iter 74: observed MAE=0.023678 rank=15
# [SoftImpute] Iter 75: observed MAE=0.023679 rank=15
# [SoftImpute] Iter 76: observed MAE=0.023679 rank=15
# [SoftImpute] Iter 77: observed MAE=0.023679 rank=15
# [SoftImpute] Iter 78: observed MAE=0.023680 rank=15
# [SoftImpute] Iter 79: observed MAE=0.023680 rank=15
# [SoftImpute] Iter 80: observed MAE=0.023681 rank=15
# [SoftImpute] Iter 81: observed MAE=0.023681 rank=15
# [SoftImpute] Iter 82: observed MAE=0.023682 rank=15
# [SoftImpute] Iter 83: observed MAE=0.023682 rank=15
# [SoftImpute] Iter 84: observed MAE=0.023682 rank=15
# [SoftImpute] Iter 85: observed MAE=0.023683 rank=15
# [SoftImpute] Iter 86: observed MAE=0.023683 rank=15
# [SoftImpute] Iter 87: observed MAE=0.023683 rank=15
# [SoftImpute] Iter 88: observed MAE=0.023684 rank=15
# [SoftImpute] Iter 89: observed MAE=0.023684 rank=15
# [SoftImpute] Iter 90: observed MAE=0.023684 rank=15
# [SoftImpute] Iter 91: observed MAE=0.023685 rank=15
# [SoftImpute] Iter 92: observed MAE=0.023685 rank=15
# [SoftImpute] Iter 93: observed MAE=0.023685 rank=15
# [SoftImpute] Iter 94: observed MAE=0.023686 rank=15
# [SoftImpute] Iter 95: observed MAE=0.023686 rank=15
# [SoftImpute] Iter 96: observed MAE=0.023686 rank=15
# [SoftImpute] Iter 97: observed MAE=0.023687 rank=15
# [SoftImpute] Iter 98: observed MAE=0.023687 rank=15
# [SoftImpute] Iter 99: observed MAE=0.023687 rank=15
# [SoftImpute] Iter 100: observed MAE=0.023687 rank=15
# [SoftImpute] Stopped after iteration 100 for lambda=0.792581
#     PatientID    ImageFile Hospital        Age  Sex     Temp_C  Cough  \
# 0       P_131    P_131.png        D  33.195797    0  39.540229      1
# 1       P_132    P_132.png        D  56.532254    0  36.868540      0
# 2       P_195    P_195.png        D  78.127837    0  37.609290      1
# 3       P_193    P_193.png        D  79.495954    0  37.647242      1
# 4       P_140    P_140.png        D  60.099710    1  36.706426      1
# ..        ...          ...      ...        ...  ...        ...    ...
# 858    P_1_12   P_1_12.png        F  50.906657    0  37.631982      0
# 859     P_1_8    P_1_8.png        F  56.559496    0  37.685975      1
# 860    P_1_10   P_1_10.png        F  38.587343    0  37.559318      0
# 861    P_1_26   P_1_26.png        F  86.273524    1  37.796539      0
# 862   P_1_146  P_1_146.png        F  83.788589    0  38.498713      0
#
#      DifficultyInBreathing        WBC         CRP  ...         LDH  \
# 0                        0   6.093142   69.719726  ...  496.069339
# 1                        0  15.473850  112.445336  ...  377.282076
# 2                        0   5.578155  166.274022  ...  317.456699
# 3                        0   6.152517  221.024658  ...  487.694021
# 4                        0   6.588651   10.085499  ...  293.305424
# ..                     ...        ...         ...  ...         ...
# 858                      1  15.758303   11.591722  ...  364.576616
# 859                      0   4.728313   -4.753165  ...  673.438149
# 860                      1   9.784796   14.395177  ...  413.931871
# 861                      1  13.986624  -13.617817  ...  345.121328
# 862                      0   7.387280  -17.018614  ...    4.839560
#
#            Ddimer  Ox_percentage       PaO2        SaO2        pH  \
# 0      449.448694      93.985011  69.231114   93.476472  7.454321
# 1      829.206335      93.716961  80.397610  100.903407  7.387528
# 2    -3524.076584      91.636093  53.125551   92.741772  7.333317
# 3     2065.672709      94.060177  52.317993   93.319404  7.423369
# 4    -1711.130157      91.842556  81.080565  103.162470  7.444999
# ..            ...            ...        ...         ...       ...
# 858  10088.772403      92.775037  74.781216   91.190706  7.452693
# 859   2403.719977      92.427919  69.328531   92.344096  7.451632
# 860   8779.018952      93.537639  74.145853   91.578637  7.449117
# 861   2402.728337      91.524438  73.120925   91.285873  7.325461
# 862   2059.530642      93.270562  87.937609   93.210850  7.463070
#
#      CardiovascularDisease  RespiratoryFailure  Prognosis severity
# 0                        0                   0       MILD        0
# 1                        0                   0       MILD        0
# 2                        1                   0     SEVERE        1
# 3                        0                   0     SEVERE        1
# 4                        0                   0       MILD        0
# ..                     ...                 ...        ...      ...
# 858                      0                   0     SEVERE        1
# 859                      0                   0     SEVERE        1
# 860                      0                   0       MILD        0
# 861                      0                   0     SEVERE        1
# 862                      1                   0       MILD        0
#
# [863 rows x 21 columns]
